# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread("watch1.jpg")
watch_face = img[75:300, 70:300]
img[0:225, 0:230] = watch_face
cv2.line(img, (230,0), (230,225), (0,255,0), 5)
cv2.line(img, (0,230), (225,230), (0,255,0), 5)
#cv2.imshow("image", img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
plt.imshow(img)
plt.show()

# %%
# Out:
# 275
